# %%
# !pip install google-cloud-speech --quiet
from pydub import AudioSegment
import os
import random
from tqdm import tqdm
from google.cloud import speech_v1p1beta1 as speech
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/tensorflow2/lib/python3.8/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
hindi_folder = "/Users/yash/Desktop/MTP-2k23-24/Wav2vec-codes/pureAudio/Hindi_female"
english_folder = "/Users/yash/Desktop/MTP-2k23-24/Wav2vec-codes/pureAudio/English_female"
output_folder_audio = "/Users/yash/Desktop/MTP-2k23-24/Wav2vec-codes/testDiralisationOutput/HE_codemixed_audio_SingleSpeakerFemale"
output_folder_rttm = "/Users/yash/Desktop/MTP-2k23-24/Wav2vec-codes/testDiralisationOutput/rttm"
file_name = "HECodemixedFemale"
count = 1
# Function to resample audio to 16 kHz
def resample_to_16k(audio_segment):
    return audio_segment.set_frame_rate(16000)

hindi_audios = [resample_to_16k(AudioSegment.from_file(f"{hindi_folder}/{file}")) for file in os.listdir(hindi_folder)]
english_audios = [resample_to_16k(AudioSegment.from_file(f"{english_folder}/{file}")) for file in os.listdir(english_folder)]

print(f"Total Hindi samples of the same speaker are: {len(hindi_audios)}")
print(f"Total English samples of the same speaker are: {len(english_audios)}")
# Out:
# Total Hindi samples of the same speaker are: 1661
# Total English samples of the same speaker are: 2913

# %%
def create_codemixed_audio_and_rttm(output_folder_audio, output_folder_rttm):
    global count
    name = file_name + str(count)
    # Set the overlap duration
    overlap_ms = 270  # 0.27 seconds
    # Randomly select the number of Hindi-English segments to join (multiple of 2 up to 8)
    num_segments = random.choice([2, 3, 4, 5, 6])
    print("Number of segments:", num_segments)
    # Randomly choose which language starts
    start_with_english = random.choice([True, False])
    # print("Start with English:", start_with_english)

    codemixed_audio = AudioSegment.silent()
    rttm_content = ""
    start_time = 0.0

    for i in range(num_segments):
        duration = None
        if len(english_audios)==0 or len(hindi_audios)==0:
            return None, None
        # Append audio segment based on starting language
        if (i % 2 == 0 and start_with_english) or (i % 2 == 1 and not start_with_english):
            random_english = random.choice(english_audios)
            english_audios.remove(random_english)
            codemixed_audio += random_english
            duration = len(random_english)
            lang_label = "English"
        else:
            random_hindi = random.choice(hindi_audios)
            hindi_audios.remove(random_hindi)
            codemixed_audio += random_hindi
            duration = len(random_hindi)
            lang_label = "Hindi"

        # Add overlap between segments
        codemixed_audio += AudioSegment.silent(duration=overlap_ms)

        # Update RTTM content
        ## Took reference from here: 
        ## https://web.archive.org/web/20100606092041if_/http://www.itl.nist.gov/iad/mig/tests/rt/2009/docs/rt09-meeting-eval-plan-v2.pdf
        rttm_content += f"Language {name} 1 {start_time:.3f} {(duration+overlap_ms)/ 1000.0:.3f} <NA> {lang_label} <NA> <NA>\n"

        # Calculate start for RTTM
        start_time = len(codemixed_audio) / 1000.0

    # Export codemixed audio
    output_audio_filename = f"{output_folder_audio}/{name}.wav"
    codemixed_audio.export(output_audio_filename, format="wav")
    count += 1

    # Export RTTM file
    output_rttm_filename = f"{output_folder_rttm}/rttm_{name}.rttm"
    with open(output_rttm_filename, "w") as rttm_file:
        rttm_file.write(rttm_content)

    return output_audio_filename, output_rttm_filename

# %%
for _ in tqdm(range(10000)):
    err, err = create_codemixed_audio_and_rttm(output_folder_audio, output_folder_rttm)
    if err is None:
        break
    print(f"Length of samples: eng->{len(english_audios)} | hin-> {len(hindi_audios)}")
# Out:
#   1%|          | 64/10000 [00:00<00:29, 333.58it/s]
# Number of segments: 5
# Length of samples: eng->2911 | hin-> 1658
# Number of segments: 2
# Length of samples: eng->2910 | hin-> 1657
# Number of segments: 2
# Length of samples: eng->2909 | hin-> 1656
# Number of segments: 3
# Length of samples: eng->2907 | hin-> 1655
# Number of segments: 3
# Length of samples: eng->2906 | hin-> 1653
# Number of segments: 3
# Length of samples: eng->2905 | hin-> 1651
# Number of segments: 5
# Length of samples: eng->2902 | hin-> 1649
# Number of segments: 3
# Length of samples: eng->2901 | hin-> 1647
# Number of segments: 6
# Length of samples: eng->2898 | hin-> 1644
# Number of segments: 4
# Length of samples: eng->2896 | hin-> 1642
# Number of segments: 2
# Length of samples: eng->2895 | hin-> 1641
# Number of segments: 2
# Length of samples: eng->2894 | hin-> 1640
# Number of segments: 4
# Length of samples: eng->2892 | hin-> 1638
# Number of segments: 6
# Length of samples: eng->2889 | hin-> 1635
# Number of segments: 5
# Length of samples: eng->2886 | hin-> 1633
# Number of segments: 5
# Length of samples: eng->2883 | hin-> 1631
# Number of segments: 5
# Length of samples: eng->2881 | hin-> 1628
# Number of segments: 3
# Length of samples: eng->2880 | hin-> 1626
# Number of segments: 6
# Length of samples: eng->2877 | hin-> 1623
# Number of segments: 6
# Length of samples: eng->2874 | hin-> 1620
# Number of segments: 6
# Length of samples: eng->2871 | hin-> 1617
# Number of segments: 6
# Length of samples: eng->2868 | hin-> 1614
# Number of segments: 4
# Length of samples: eng->2866 | hin-> 1612
# Number of segments: 4
# Length of samples: eng->2864 | hin-> 1610
# Number of segments: 3
# Length of samples: eng->2862 | hin-> 1609
# Number of segments: 5
# Length of samples: eng->2859 | hin-> 1607
# Number of segments: 2
# Length of samples: eng->2858 | hin-> 1606
# Number of segments: 2
# Length of samples: eng->2857 | hin-> 1605
# Number of segments: 4
# Length of samples: eng->2855 | hin-> 1603
# Number of segments: 5
# Length of samples: eng->2852 | hin-> 1601
# Number of segments: 4
# Length of samples: eng->2850 | hin-> 1599
# Number of segments: 4
# Length of samples: eng->2848 | hin-> 1597
# Number of segments: 5
# Length of samples: eng->2845 | hin-> 1595
# Number of segments: 6
# Length of samples: eng->2842 | hin-> 1592
# Number of segments: 2
# Length of samples: eng->2841 | hin-> 1591
# Number of segments: 5
# Length of samples: eng->2838 | hin-> 1589
# Number of segments: 6
# Length of samples: eng->2835 | hin-> 1586
# Number of segments: 3
# Length of samples: eng->2834 | hin-> 1584
# Number of segments: 3
# Length of samples: eng->2832 | hin-> 1583
# Number of segments: 5
# Length of samples: eng->2830 | hin-> 1580
# Number of segments: 4
# Length of samples: eng->2828 | hin-> 1578
# Number of segments: 2
# Length of samples: eng->2827 | hin-> 1577
# Number of segments: 4
# Length of samples: eng->2825 | hin-> 1575
# Number of segments: 4
# Length of samples: eng->2823 | hin-> 1573
# Number of segments: 2
# Length of samples: eng->2822 | hin-> 1572
# Number of segments: 2
# Length of samples: eng->2821 | hin-> 1571
# Number of segments: 2
# Length of samples: eng->2820 | hin-> 1570
# Number of segments: 4
# Length of samples: eng->2818 | hin-> 1568
# Number of segments: 5
# Length of samples: eng->2816 | hin-> 1565
# Number of segments: 5
# Length of samples: eng->2814 | hin-> 1562
# Number of segments: 6
# Length of samples: eng->2811 | hin-> 1559
# Number of segments: 6
# Length of samples: eng->2808 | hin-> 1556
# Number of segments: 4
# Length of samples: eng->2806 | hin-> 1554
# Number of segments: 6
# Length of samples: eng->2803 | hin-> 1551
# Number of segments: 4
# Length of samples: eng->2801 | hin-> 1549
# Number of segments: 4
# Length of samples: eng->2799 | hin-> 1547
# Number of segments: 5
# Length of samples: eng->2796 | hin-> 1545
# Number of segments: 5
# Length of samples: eng->2793 | hin-> 1543
# Number of segments: 3
# Length of samples: eng->2792 | hin-> 1541
# Number of segments: 4
# Length of samples: eng->2790 | hin-> 1539
# Number of segments: 2
# Length of samples: eng->2789 | hin-> 1538
# Number of segments: 4
# Length of samples: eng->2787 | hin-> 1536
# Number of segments: 6
# Length of samples: eng->2784 | hin-> 1533
# Number of segments: 6
# Length of samples: eng->2781 | hin-> 1530
# Number of segments: 3
# Length of samples: eng->2779 | hin-> 1529
# Number of segments: 3
# Length of samples: eng->2778 | hin-> 1527
# Number of segments: 4
# Length of samples: eng->2776 | hin-> 1525
# Number of segments: 5
# Length of samples: eng->2774 | hin-> 1522
# Number of segments: 2
# Length of samples: eng->2773 | hin-> 1521
# Number of segments: 6
#   1%|          | 98/10000 [00:00<00:33, 292.61it/s]
# Length of samples: eng->2770 | hin-> 1518
# Number of segments: 3
# Length of samples: eng->2768 | hin-> 1517
# Number of segments: 2
# Length of samples: eng->2767 | hin-> 1516
# Number of segments: 4
# Length of samples: eng->2765 | hin-> 1514
# Number of segments: 2
# Length of samples: eng->2764 | hin-> 1513
# Number of segments: 2
# Length of samples: eng->2763 | hin-> 1512
# Number of segments: 4
# Length of samples: eng->2761 | hin-> 1510
# Number of segments: 6
# Length of samples: eng->2758 | hin-> 1507
# Number of segments: 5
# Length of samples: eng->2755 | hin-> 1505
# Number of segments: 6
# Length of samples: eng->2752 | hin-> 1502
# Number of segments: 4
# Length of samples: eng->2750 | hin-> 1500
# Number of segments: 4
# Length of samples: eng->2748 | hin-> 1498
# Number of segments: 6
# Length of samples: eng->2745 | hin-> 1495
# Number of segments: 3
# Length of samples: eng->2743 | hin-> 1494
# Number of segments: 2
# Length of samples: eng->2742 | hin-> 1493
# Number of segments: 2
# Length of samples: eng->2741 | hin-> 1492
# Number of segments: 6
# Length of samples: eng->2738 | hin-> 1489
# Number of segments: 5
# Length of samples: eng->2736 | hin-> 1486
# Number of segments: 2
# Length of samples: eng->2735 | hin-> 1485
# Number of segments: 2
# Length of samples: eng->2734 | hin-> 1484
# Number of segments: 5
# Length of samples: eng->2731 | hin-> 1482
# Number of segments: 3
# Length of samples: eng->2729 | hin-> 1481
# Number of segments: 6
# Length of samples: eng->2726 | hin-> 1478
# Number of segments: 5
# Length of samples: eng->2724 | hin-> 1475
# Number of segments: 4
# Length of samples: eng->2722 | hin-> 1473
# Number of segments: 2
# Length of samples: eng->2721 | hin-> 1472
# Number of segments: 6
# Length of samples: eng->2718 | hin-> 1469
# Number of segments: 6
# Length of samples: eng->2715 | hin-> 1466
# Number of segments: 2
# Length of samples: eng->2714 | hin-> 1465
# Number of segments: 2
# Length of samples: eng->2713 | hin-> 1464
# Number of segments: 2
# Length of samples: eng->2712 | hin-> 1463
# Number of segments: 4
# Length of samples: eng->2710 | hin-> 1461
# Number of segments: 4
# Length of samples: eng->2708 | hin-> 1459
# Number of segments: 5
# Length of samples: eng->2705 | hin-> 1457
# Number of segments: 2
# Length of samples: eng->2704 | hin-> 1456
# Number of segments: 3
# Length of samples: eng->2703 | hin-> 1454
# Number of segments: 6
# Length of samples: eng->2700 | hin-> 1451
# Number of segments: 5
# Length of samples: eng->2698 | hin-> 1448
# Number of segments: 4
# Length of samples: eng->2696 | hin-> 1446
# Number of segments: 4
# Length of samples: eng->2694 | hin-> 1444
# Number of segments: 6
# Length of samples: eng->2691 | hin-> 1441
# Number of segments: 6
# Length of samples: eng->2688 | hin-> 1438
# Number of segments: 2
# Length of samples: eng->2687 | hin-> 1437
# Number of segments: 3
# Length of samples: eng->2686 | hin-> 1435
# Number of segments: 5
# Length of samples: eng->2683 | hin-> 1433
# Number of segments: 3
# Length of samples: eng->2682 | hin-> 1431
# Number of segments: 5
# Length of samples: eng->2680 | hin-> 1428
# Number of segments: 5
# Length of samples: eng->2677 | hin-> 1426
# Number of segments: 4
# Length of samples: eng->2675 | hin-> 1424
# Number of segments: 5
# Length of samples: eng->2673 | hin-> 1421
# Number of segments: 6
# Length of samples: eng->2670 | hin-> 1418
# Number of segments: 5
# Length of samples: eng->2667 | hin-> 1416
# Number of segments: 3
# Length of samples: eng->2665 | hin-> 1415
# Number of segments: 5
# Length of samples: eng->2662 | hin-> 1413
# Number of segments: 5
# Length of samples: eng->2659 | hin-> 1411
# Number of segments: 2
# Length of samples: eng->2658 | hin-> 1410
# Number of segments: 6
# Length of samples: eng->2655 | hin-> 1407
# Number of segments: 4
# Length of samples: eng->2653 | hin-> 1405
# Number of segments: 2
# Length of samples: eng->2652 | hin-> 1404
# Number of segments: 6
# Length of samples: eng->2649 | hin-> 1401
# Number of segments: 4
# Length of samples: eng->2647 | hin-> 1399
# Number of segments: 6
#   2%|▏         | 178/10000 [00:00<00:28, 349.37it/s]
# Length of samples: eng->2644 | hin-> 1396
# Number of segments: 2
# Length of samples: eng->2643 | hin-> 1395
# Number of segments: 6
# Length of samples: eng->2640 | hin-> 1392
# Number of segments: 4
# Length of samples: eng->2638 | hin-> 1390
# Number of segments: 2
# Length of samples: eng->2637 | hin-> 1389
# Number of segments: 4
# Length of samples: eng->2635 | hin-> 1387
# Number of segments: 5
# Length of samples: eng->2632 | hin-> 1385
# Number of segments: 3
# Length of samples: eng->2631 | hin-> 1383
# Number of segments: 5
# Length of samples: eng->2628 | hin-> 1381
# Number of segments: 2
# Length of samples: eng->2627 | hin-> 1380
# Number of segments: 6
# Length of samples: eng->2624 | hin-> 1377
# Number of segments: 6
# Length of samples: eng->2621 | hin-> 1374
# Number of segments: 3
# Length of samples: eng->2620 | hin-> 1372
# Number of segments: 4
# Length of samples: eng->2618 | hin-> 1370
# Number of segments: 4
# Length of samples: eng->2616 | hin-> 1368
# Number of segments: 5
# Length of samples: eng->2613 | hin-> 1366
# Number of segments: 6
# Length of samples: eng->2610 | hin-> 1363
# Number of segments: 5
# Length of samples: eng->2608 | hin-> 1360
# Number of segments: 2
# Length of samples: eng->2607 | hin-> 1359
# Number of segments: 5
# Length of samples: eng->2604 | hin-> 1357
# Number of segments: 6
# Length of samples: eng->2601 | hin-> 1354
# Number of segments: 5
# Length of samples: eng->2598 | hin-> 1352
# Number of segments: 3
# Length of samples: eng->2597 | hin-> 1350
# Number of segments: 2
# Length of samples: eng->2596 | hin-> 1349
# Number of segments: 6
# Length of samples: eng->2593 | hin-> 1346
# Number of segments: 4
# Length of samples: eng->2591 | hin-> 1344
# Number of segments: 6
# Length of samples: eng->2588 | hin-> 1341
# Number of segments: 6
# Length of samples: eng->2585 | hin-> 1338
# Number of segments: 4
# Length of samples: eng->2583 | hin-> 1336
# Number of segments: 3
# Length of samples: eng->2581 | hin-> 1335
# Number of segments: 4
# Length of samples: eng->2579 | hin-> 1333
# Number of segments: 6
# Length of samples: eng->2576 | hin-> 1330
# Number of segments: 3
# Length of samples: eng->2575 | hin-> 1328
# Number of segments: 2
# Length of samples: eng->2574 | hin-> 1327
# Number of segments: 6
# Length of samples: eng->2571 | hin-> 1324
# Number of segments: 2
# Length of samples: eng->2570 | hin-> 1323
# Number of segments: 4
# Length of samples: eng->2568 | hin-> 1321
# Number of segments: 6
# Length of samples: eng->2565 | hin-> 1318
# Number of segments: 5
# Length of samples: eng->2562 | hin-> 1316
# Number of segments: 2
# Length of samples: eng->2561 | hin-> 1315
# Number of segments: 6
# Length of samples: eng->2558 | hin-> 1312
# Number of segments: 6
# Length of samples: eng->2555 | hin-> 1309
# Number of segments: 2
# Length of samples: eng->2554 | hin-> 1308
# Number of segments: 2
# Length of samples: eng->2553 | hin-> 1307
# Number of segments: 3
# Length of samples: eng->2552 | hin-> 1305
# Number of segments: 2
# Length of samples: eng->2551 | hin-> 1304
# Number of segments: 3
# Length of samples: eng->2550 | hin-> 1302
# Number of segments: 4
# Length of samples: eng->2548 | hin-> 1300
# Number of segments: 6
# Length of samples: eng->2545 | hin-> 1297
# Number of segments: 3
# Length of samples: eng->2543 | hin-> 1296
# Number of segments: 2
# Length of samples: eng->2542 | hin-> 1295
# Number of segments: 4
# Length of samples: eng->2540 | hin-> 1293
# Number of segments: 6
# Length of samples: eng->2537 | hin-> 1290
# Number of segments: 4
# Length of samples: eng->2535 | hin-> 1288
# Number of segments: 4
# Length of samples: eng->2533 | hin-> 1286
# Number of segments: 4
# Length of samples: eng->2531 | hin-> 1284
# Number of segments: 2
# Length of samples: eng->2530 | hin-> 1283
# Number of segments: 2
# Length of samples: eng->2529 | hin-> 1282
# Number of segments: 3
# Length of samples: eng->2527 | hin-> 1281
# Number of segments: 5
# Length of samples: eng->2524 | hin-> 1279
# Number of segments: 3
# Length of samples: eng->2523 | hin-> 1277
# Number of segments: 2
# Length of samples: eng->2522 | hin-> 1276
# Number of segments: 3
# Length of samples: eng->2520 | hin-> 1275
# Number of segments: 6
# Length of samples: eng->2517 | hin-> 1272
# Number of segments: 2
# Length of samples: eng->2516 | hin-> 1271
# Number of segments: 6
# Length of samples: eng->2513 | hin-> 1268
# Number of segments: 4
# Length of samples: eng->2511 | hin-> 1266
# Number of segments: 5
# Length of samples: eng->2509 | hin-> 1263
# Number of segments: 4
# Length of samples: eng->2507 | hin-> 1261
# Number of segments: 4
# Length of samples: eng->2505 | hin-> 1259
# Number of segments: 4
# Length of samples: eng->2503 | hin-> 1257
# Number of segments: 6
# Length of samples: eng->2500 | hin-> 1254
# Number of segments: 3
# Length of samples: eng->2499 | hin-> 1252
# Number of segments: 5
# Length of samples: eng->2496 | hin-> 1250
# Number of segments: 4
# Length of samples: eng->2494 | hin-> 1248
# Number of segments: 5
# Length of samples: eng->2491 | hin-> 1246
# Number of segments: 6
# Length of samples: eng->2488 | hin-> 1243
# Number of segments: 2
# Length of samples: eng->2487 | hin-> 1242
# Number of segments: 5
# Length of samples: eng->2484 | hin-> 1240
# Number of segments: 3
# Length of samples: eng->2482 | hin-> 1239
# Number of segments: 4
# Length of samples: eng->2480 | hin-> 1237
# Number of segments: 5
# Length of samples: eng->2478 | hin-> 1234
# Number of segments: 5
# Length of samples: eng->2475 | hin-> 1232
# Number of segments: 5
# Length of samples: eng->2472 | hin-> 1230
# Number of segments: 5
#   3%|▎         | 259/10000 [00:00<00:26, 370.76it/s]
# Length of samples: eng->2470 | hin-> 1227
# Number of segments: 5
# Length of samples: eng->2468 | hin-> 1224
# Number of segments: 6
# Length of samples: eng->2465 | hin-> 1221
# Number of segments: 4
# Length of samples: eng->2463 | hin-> 1219
# Number of segments: 4
# Length of samples: eng->2461 | hin-> 1217
# Number of segments: 2
# Length of samples: eng->2460 | hin-> 1216
# Number of segments: 4
# Length of samples: eng->2458 | hin-> 1214
# Number of segments: 6
# Length of samples: eng->2455 | hin-> 1211
# Number of segments: 5
# Length of samples: eng->2452 | hin-> 1209
# Number of segments: 5
# Length of samples: eng->2450 | hin-> 1206
# Number of segments: 3
# Length of samples: eng->2448 | hin-> 1205
# Number of segments: 2
# Length of samples: eng->2447 | hin-> 1204
# Number of segments: 5
# Length of samples: eng->2445 | hin-> 1201
# Number of segments: 3
# Length of samples: eng->2444 | hin-> 1199
# Number of segments: 3
# Length of samples: eng->2442 | hin-> 1198
# Number of segments: 3
# Length of samples: eng->2441 | hin-> 1196
# Number of segments: 2
# Length of samples: eng->2440 | hin-> 1195
# Number of segments: 6
# Length of samples: eng->2437 | hin-> 1192
# Number of segments: 6
# Length of samples: eng->2434 | hin-> 1189
# Number of segments: 4
# Length of samples: eng->2432 | hin-> 1187
# Number of segments: 3
# Length of samples: eng->2431 | hin-> 1185
# Number of segments: 2
# Length of samples: eng->2430 | hin-> 1184
# Number of segments: 6
# Length of samples: eng->2427 | hin-> 1181
# Number of segments: 6
# Length of samples: eng->2424 | hin-> 1178
# Number of segments: 3
# Length of samples: eng->2422 | hin-> 1177
# Number of segments: 6
# Length of samples: eng->2419 | hin-> 1174
# Number of segments: 6
# Length of samples: eng->2416 | hin-> 1171
# Number of segments: 4
# Length of samples: eng->2414 | hin-> 1169
# Number of segments: 3
# Length of samples: eng->2413 | hin-> 1167
# Number of segments: 6
# Length of samples: eng->2410 | hin-> 1164
# Number of segments: 6
# Length of samples: eng->2407 | hin-> 1161
# Number of segments: 2
# Length of samples: eng->2406 | hin-> 1160
# Number of segments: 2
# Length of samples: eng->2405 | hin-> 1159
# Number of segments: 6
# Length of samples: eng->2402 | hin-> 1156
# Number of segments: 6
# Length of samples: eng->2399 | hin-> 1153
# Number of segments: 3
# Length of samples: eng->2397 | hin-> 1152
# Number of segments: 3
# Length of samples: eng->2395 | hin-> 1151
# Number of segments: 4
# Length of samples: eng->2393 | hin-> 1149
# Number of segments: 6
# Length of samples: eng->2390 | hin-> 1146
# Number of segments: 3
# Length of samples: eng->2389 | hin-> 1144
# Number of segments: 5
# Length of samples: eng->2387 | hin-> 1141
# Number of segments: 4
# Length of samples: eng->2385 | hin-> 1139
# Number of segments: 3
# Length of samples: eng->2383 | hin-> 1138
# Number of segments: 2
# Length of samples: eng->2382 | hin-> 1137
# Number of segments: 3
# Length of samples: eng->2380 | hin-> 1136
# Number of segments: 2
# Length of samples: eng->2379 | hin-> 1135
# Number of segments: 4
# Length of samples: eng->2377 | hin-> 1133
# Number of segments: 4
# Length of samples: eng->2375 | hin-> 1131
# Number of segments: 6
# Length of samples: eng->2372 | hin-> 1128
# Number of segments: 2
# Length of samples: eng->2371 | hin-> 1127
# Number of segments: 4
# Length of samples: eng->2369 | hin-> 1125
# Number of segments: 6
# Length of samples: eng->2366 | hin-> 1122
# Number of segments: 4
# Length of samples: eng->2364 | hin-> 1120
# Number of segments: 6
# Length of samples: eng->2361 | hin-> 1117
# Number of segments: 6
# Length of samples: eng->2358 | hin-> 1114
# Number of segments: 3
# Length of samples: eng->2356 | hin-> 1113
# Number of segments: 3
# Length of samples: eng->2355 | hin-> 1111
# Number of segments: 2
# Length of samples: eng->2354 | hin-> 1110
# Number of segments: 2
# Length of samples: eng->2353 | hin-> 1109
# Number of segments: 5
# Length of samples: eng->2351 | hin-> 1106
# Number of segments: 5
# Length of samples: eng->2349 | hin-> 1103
# Number of segments: 3
# Length of samples: eng->2347 | hin-> 1102
# Number of segments: 5
# Length of samples: eng->2344 | hin-> 1100
# Number of segments: 3
# Length of samples: eng->2342 | hin-> 1099
# Number of segments: 4
# Length of samples: eng->2340 | hin-> 1097
# Number of segments: 4
# Length of samples: eng->2338 | hin-> 1095
# Number of segments: 5
# Length of samples: eng->2336 | hin-> 1092
# Number of segments: 6
# Length of samples: eng->2333 | hin-> 1089
# Number of segments: 6
# Length of samples: eng->2330 | hin-> 1086
# Number of segments: 5
# Length of samples: eng->2328 | hin-> 1083
# Number of segments: 5
# Length of samples: eng->2325 | hin-> 1081
# Number of segments: 2
# Length of samples: eng->2324 | hin-> 1080
# Number of segments: 3
# Length of samples: eng->2322 | hin-> 1079
# Number of segments: 4
# Length of samples: eng->2320 | hin-> 1077
# Number of segments: 5
# Length of samples: eng->2317 | hin-> 1075
# Number of segments: 3
# Length of samples: eng->2316 | hin-> 1073
# Number of segments: 4
# Length of samples: eng->2314 | hin-> 1071
# Number of segments: 6
# Length of samples: eng->2311 | hin-> 1068
# Number of segments: 5
# Length of samples: eng->2309 | hin-> 1065
# Number of segments: 3
# Length of samples: eng->2307 | hin-> 1064
# Number of segments: 2
# Length of samples: eng->2306 | hin-> 1063
# Number of segments: 4
# Length of samples: eng->2304 | hin-> 1061
# Number of segments: 6
#   3%|▎         | 344/10000 [00:00<00:24, 395.15it/s]
# Length of samples: eng->2301 | hin-> 1058
# Number of segments: 5
# Length of samples: eng->2299 | hin-> 1055
# Number of segments: 6
# Length of samples: eng->2296 | hin-> 1052
# Number of segments: 4
# Length of samples: eng->2294 | hin-> 1050
# Number of segments: 6
# Length of samples: eng->2291 | hin-> 1047
# Number of segments: 4
# Length of samples: eng->2289 | hin-> 1045
# Number of segments: 4
# Length of samples: eng->2287 | hin-> 1043
# Number of segments: 2
# Length of samples: eng->2286 | hin-> 1042
# Number of segments: 4
# Length of samples: eng->2284 | hin-> 1040
# Number of segments: 3
# Length of samples: eng->2282 | hin-> 1039
# Number of segments: 3
# Length of samples: eng->2281 | hin-> 1037
# Number of segments: 3
# Length of samples: eng->2279 | hin-> 1036
# Number of segments: 5
# Length of samples: eng->2276 | hin-> 1034
# Number of segments: 4
# Length of samples: eng->2274 | hin-> 1032
# Number of segments: 5
# Length of samples: eng->2272 | hin-> 1029
# Number of segments: 3
# Length of samples: eng->2270 | hin-> 1028
# Number of segments: 3
# Length of samples: eng->2268 | hin-> 1027
# Number of segments: 4
# Length of samples: eng->2266 | hin-> 1025
# Number of segments: 3
# Length of samples: eng->2265 | hin-> 1023
# Number of segments: 6
# Length of samples: eng->2262 | hin-> 1020
# Number of segments: 5
# Length of samples: eng->2259 | hin-> 1018
# Number of segments: 3
# Length of samples: eng->2257 | hin-> 1017
# Number of segments: 2
# Length of samples: eng->2256 | hin-> 1016
# Number of segments: 5
# Length of samples: eng->2253 | hin-> 1014
# Number of segments: 3
# Length of samples: eng->2252 | hin-> 1012
# Number of segments: 2
# Length of samples: eng->2251 | hin-> 1011
# Number of segments: 4
# Length of samples: eng->2249 | hin-> 1009
# Number of segments: 4
# Length of samples: eng->2247 | hin-> 1007
# Number of segments: 3
# Length of samples: eng->2245 | hin-> 1006
# Number of segments: 2
# Length of samples: eng->2244 | hin-> 1005
# Number of segments: 5
# Length of samples: eng->2242 | hin-> 1002
# Number of segments: 6
# Length of samples: eng->2239 | hin-> 999
# Number of segments: 2
# Length of samples: eng->2238 | hin-> 998
# Number of segments: 2
# Length of samples: eng->2237 | hin-> 997
# Number of segments: 3
# Length of samples: eng->2235 | hin-> 996
# Number of segments: 3
# Length of samples: eng->2234 | hin-> 994
# Number of segments: 5
# Length of samples: eng->2232 | hin-> 991
# Number of segments: 6
# Length of samples: eng->2229 | hin-> 988
# Number of segments: 6
# Length of samples: eng->2226 | hin-> 985
# Number of segments: 6
# Length of samples: eng->2223 | hin-> 982
# Number of segments: 5
# Length of samples: eng->2220 | hin-> 980
# Number of segments: 5
# Length of samples: eng->2218 | hin-> 977
# Number of segments: 2
# Length of samples: eng->2217 | hin-> 976
# Number of segments: 3
# Length of samples: eng->2216 | hin-> 974
# Number of segments: 4
# Length of samples: eng->2214 | hin-> 972
# Number of segments: 5
# Length of samples: eng->2211 | hin-> 970
# Number of segments: 4
# Length of samples: eng->2209 | hin-> 968
# Number of segments: 4
# Length of samples: eng->2207 | hin-> 966
# Number of segments: 2
# Length of samples: eng->2206 | hin-> 965
# Number of segments: 4
# Length of samples: eng->2204 | hin-> 963
# Number of segments: 4
# Length of samples: eng->2202 | hin-> 961
# Number of segments: 6
# Length of samples: eng->2199 | hin-> 958
# Number of segments: 3
# Length of samples: eng->2197 | hin-> 957
# Number of segments: 4
# Length of samples: eng->2195 | hin-> 955
# Number of segments: 4
# Length of samples: eng->2193 | hin-> 953
# Number of segments: 6
# Length of samples: eng->2190 | hin-> 950
# Number of segments: 5
# Length of samples: eng->2187 | hin-> 948
# Number of segments: 4
# Length of samples: eng->2185 | hin-> 946
# Number of segments: 3
# Length of samples: eng->2183 | hin-> 945
# Number of segments: 4
# Length of samples: eng->2181 | hin-> 943
# Number of segments: 6
# Length of samples: eng->2178 | hin-> 940
# Number of segments: 4
# Length of samples: eng->2176 | hin-> 938
# Number of segments: 6
# Length of samples: eng->2173 | hin-> 935
# Number of segments: 6
# Length of samples: eng->2170 | hin-> 932
# Number of segments: 3
# Length of samples: eng->2169 | hin-> 930
# Number of segments: 6
# Length of samples: eng->2166 | hin-> 927
# Number of segments: 6
# Length of samples: eng->2163 | hin-> 924
# Number of segments: 4
# Length of samples: eng->2161 | hin-> 922
# Number of segments: 6
# Length of samples: eng->2158 | hin-> 919
# Number of segments: 3
# Length of samples: eng->2157 | hin-> 917
# Number of segments: 2
# Length of samples: eng->2156 | hin-> 916
# Number of segments: 5
# Length of samples: eng->2154 | hin-> 913
# Number of segments: 4
# Length of samples: eng->2152 | hin-> 911
# Number of segments: 6
# Length of samples: eng->2149 | hin-> 908
# Number of segments: 2
# Length of samples: eng->2148 | hin-> 907
# Number of segments: 2
# Length of samples: eng->2147 | hin-> 906
# Number of segments: 4
# Length of samples: eng->2145 | hin-> 904
# Number of segments: 5
# Length of samples: eng->2143 | hin-> 901
# Number of segments: 5
# Length of samples: eng->2140 | hin-> 899
# Number of segments: 3
# Length of samples: eng->2139 | hin-> 897
# Number of segments: 4
#   4%|▍         | 425/10000 [00:01<00:24, 388.32it/s]
# Length of samples: eng->2137 | hin-> 895
# Number of segments: 6
# Length of samples: eng->2134 | hin-> 892
# Number of segments: 4
# Length of samples: eng->2132 | hin-> 890
# Number of segments: 5
# Length of samples: eng->2130 | hin-> 887
# Number of segments: 6
# Length of samples: eng->2127 | hin-> 884
# Number of segments: 5
# Length of samples: eng->2125 | hin-> 881
# Number of segments: 5
# Length of samples: eng->2122 | hin-> 879
# Number of segments: 4
# Length of samples: eng->2120 | hin-> 877
# Number of segments: 4
# Length of samples: eng->2118 | hin-> 875
# Number of segments: 6
# Length of samples: eng->2115 | hin-> 872
# Number of segments: 6
# Length of samples: eng->2112 | hin-> 869
# Number of segments: 3
# Length of samples: eng->2110 | hin-> 868
# Number of segments: 3
# Length of samples: eng->2108 | hin-> 867
# Number of segments: 5
# Length of samples: eng->2106 | hin-> 864
# Number of segments: 3
# Length of samples: eng->2105 | hin-> 862
# Number of segments: 5
# Length of samples: eng->2103 | hin-> 859
# Number of segments: 5
# Length of samples: eng->2100 | hin-> 857
# Number of segments: 2
# Length of samples: eng->2099 | hin-> 856
# Number of segments: 4
# Length of samples: eng->2097 | hin-> 854
# Number of segments: 6
# Length of samples: eng->2094 | hin-> 851
# Number of segments: 2
# Length of samples: eng->2093 | hin-> 850
# Number of segments: 2
# Length of samples: eng->2092 | hin-> 849
# Number of segments: 4
# Length of samples: eng->2090 | hin-> 847
# Number of segments: 2
# Length of samples: eng->2089 | hin-> 846
# Number of segments: 5
# Length of samples: eng->2086 | hin-> 844
# Number of segments: 2
# Length of samples: eng->2085 | hin-> 843
# Number of segments: 2
# Length of samples: eng->2084 | hin-> 842
# Number of segments: 3
# Length of samples: eng->2083 | hin-> 840
# Number of segments: 4
# Length of samples: eng->2081 | hin-> 838
# Number of segments: 4
# Length of samples: eng->2079 | hin-> 836
# Number of segments: 5
# Length of samples: eng->2076 | hin-> 834
# Number of segments: 3
# Length of samples: eng->2074 | hin-> 833
# Number of segments: 5
# Length of samples: eng->2072 | hin-> 830
# Number of segments: 3
# Length of samples: eng->2071 | hin-> 828
# Number of segments: 2
# Length of samples: eng->2070 | hin-> 827
# Number of segments: 2
# Length of samples: eng->2069 | hin-> 826
# Number of segments: 4
# Length of samples: eng->2067 | hin-> 824
# Number of segments: 6
# Length of samples: eng->2064 | hin-> 821
# Number of segments: 4
# Length of samples: eng->2062 | hin-> 819
# Number of segments: 6
# Length of samples: eng->2059 | hin-> 816
# Number of segments: 5
# Length of samples: eng->2057 | hin-> 813
# Number of segments: 2
# Length of samples: eng->2056 | hin-> 812
# Number of segments: 5
# Length of samples: eng->2053 | hin-> 810
# Number of segments: 4
# Length of samples: eng->2051 | hin-> 808
# Number of segments: 5
# Length of samples: eng->2048 | hin-> 806
# Number of segments: 3
# Length of samples: eng->2046 | hin-> 805
# Number of segments: 2
# Length of samples: eng->2045 | hin-> 804
# Number of segments: 3
# Length of samples: eng->2044 | hin-> 802
# Number of segments: 6
# Length of samples: eng->2041 | hin-> 799
# Number of segments: 5
# Length of samples: eng->2039 | hin-> 796
# Number of segments: 5
# Length of samples: eng->2037 | hin-> 793
# Number of segments: 2
# Length of samples: eng->2036 | hin-> 792
# Number of segments: 4
# Length of samples: eng->2034 | hin-> 790
# Number of segments: 4
# Length of samples: eng->2032 | hin-> 788
# Number of segments: 4
# Length of samples: eng->2030 | hin-> 786
# Number of segments: 2
# Length of samples: eng->2029 | hin-> 785
# Number of segments: 3
# Length of samples: eng->2027 | hin-> 784
# Number of segments: 3
# Length of samples: eng->2025 | hin-> 783
# Number of segments: 6
# Length of samples: eng->2022 | hin-> 780
# Number of segments: 3
# Length of samples: eng->2021 | hin-> 778
# Number of segments: 2
# Length of samples: eng->2020 | hin-> 777
# Number of segments: 3
# Length of samples: eng->2019 | hin-> 775
# Number of segments: 5
# Length of samples: eng->2016 | hin-> 773
# Number of segments: 3
# Length of samples: eng->2015 | hin-> 771
# Number of segments: 4
# Length of samples: eng->2013 | hin-> 769
# Number of segments: 3
# Length of samples: eng->2011 | hin-> 768
# Number of segments: 3
# Length of samples: eng->2009 | hin-> 767
# Number of segments: 5
# Length of samples: eng->2006 | hin-> 765
# Number of segments: 3
# Length of samples: eng->2004 | hin-> 764
# Number of segments: 4
# Length of samples: eng->2002 | hin-> 762
# Number of segments: 4
# Length of samples: eng->2000 | hin-> 760
# Number of segments: 2
# Length of samples: eng->1999 | hin-> 759
# Number of segments: 6
# Length of samples: eng->1996 | hin-> 756
# Number of segments: 3
# Length of samples: eng->1994 | hin-> 755
# Number of segments: 3
# Length of samples: eng->1993 | hin-> 753
# Number of segments: 2
# Length of samples: eng->1992 | hin-> 752
# Number of segments: 5
# Length of samples: eng->1990 | hin-> 749
# Number of segments: 6
# Length of samples: eng->1987 | hin-> 746
# Number of segments: 5
# Length of samples: eng->1985 | hin-> 743
# Number of segments: 5
# Length of samples: eng->1982 | hin-> 741
# Number of segments: 5
# Length of samples: eng->1979 | hin-> 739
# Number of segments: 6
#   5%|▌         | 508/10000 [00:01<00:23, 397.70it/s]
# Length of samples: eng->1976 | hin-> 736
# Number of segments: 5
# Length of samples: eng->1974 | hin-> 733
# Number of segments: 5
# Length of samples: eng->1972 | hin-> 730
# Number of segments: 2
# Length of samples: eng->1971 | hin-> 729
# Number of segments: 3
# Length of samples: eng->1969 | hin-> 728
# Number of segments: 6
# Length of samples: eng->1966 | hin-> 725
# Number of segments: 6
# Length of samples: eng->1963 | hin-> 722
# Number of segments: 4
# Length of samples: eng->1961 | hin-> 720
# Number of segments: 5
# Length of samples: eng->1958 | hin-> 718
# Number of segments: 4
# Length of samples: eng->1956 | hin-> 716
# Number of segments: 6
# Length of samples: eng->1953 | hin-> 713
# Number of segments: 6
# Length of samples: eng->1950 | hin-> 710
# Number of segments: 6
# Length of samples: eng->1947 | hin-> 707
# Number of segments: 5
# Length of samples: eng->1944 | hin-> 705
# Number of segments: 4
# Length of samples: eng->1942 | hin-> 703
# Number of segments: 4
# Length of samples: eng->1940 | hin-> 701
# Number of segments: 5
# Length of samples: eng->1938 | hin-> 698
# Number of segments: 4
# Length of samples: eng->1936 | hin-> 696
# Number of segments: 5
# Length of samples: eng->1933 | hin-> 694
# Number of segments: 6
# Length of samples: eng->1930 | hin-> 691
# Number of segments: 4
# Length of samples: eng->1928 | hin-> 689
# Number of segments: 4
# Length of samples: eng->1926 | hin-> 687
# Number of segments: 4
# Length of samples: eng->1924 | hin-> 685
# Number of segments: 6
# Length of samples: eng->1921 | hin-> 682
# Number of segments: 5
# Length of samples: eng->1918 | hin-> 680
# Number of segments: 3
# Length of samples: eng->1916 | hin-> 679
# Number of segments: 5
# Length of samples: eng->1914 | hin-> 676
# Number of segments: 5
# Length of samples: eng->1911 | hin-> 674
# Number of segments: 4
# Length of samples: eng->1909 | hin-> 672
# Number of segments: 5
# Length of samples: eng->1906 | hin-> 670
# Number of segments: 3
# Length of samples: eng->1905 | hin-> 668
# Number of segments: 3
# Length of samples: eng->1904 | hin-> 666
# Number of segments: 6
# Length of samples: eng->1901 | hin-> 663
# Number of segments: 2
# Length of samples: eng->1900 | hin-> 662
# Number of segments: 6
# Length of samples: eng->1897 | hin-> 659
# Number of segments: 5
# Length of samples: eng->1895 | hin-> 656
# Number of segments: 5
# Length of samples: eng->1892 | hin-> 654
# Number of segments: 3
# Length of samples: eng->1890 | hin-> 653
# Number of segments: 6
# Length of samples: eng->1887 | hin-> 650
# Number of segments: 4
# Length of samples: eng->1885 | hin-> 648
# Number of segments: 6
# Length of samples: eng->1882 | hin-> 645
# Number of segments: 6
# Length of samples: eng->1879 | hin-> 642
# Number of segments: 4
# Length of samples: eng->1877 | hin-> 640
# Number of segments: 6
# Length of samples: eng->1874 | hin-> 637
# Number of segments: 5
# Length of samples: eng->1871 | hin-> 635
# Number of segments: 6
# Length of samples: eng->1868 | hin-> 632
# Number of segments: 4
# Length of samples: eng->1866 | hin-> 630
# Number of segments: 4
# Length of samples: eng->1864 | hin-> 628
# Number of segments: 4
# Length of samples: eng->1862 | hin-> 626
# Number of segments: 2
# Length of samples: eng->1861 | hin-> 625
# Number of segments: 4
# Length of samples: eng->1859 | hin-> 623
# Number of segments: 2
# Length of samples: eng->1858 | hin-> 622
# Number of segments: 5
# Length of samples: eng->1855 | hin-> 620
# Number of segments: 5
# Length of samples: eng->1852 | hin-> 618
# Number of segments: 6
# Length of samples: eng->1849 | hin-> 615
# Number of segments: 6
# Length of samples: eng->1846 | hin-> 612
# Number of segments: 5
# Length of samples: eng->1843 | hin-> 610
# Number of segments: 3
# Length of samples: eng->1841 | hin-> 609
# Number of segments: 4
# Length of samples: eng->1839 | hin-> 607
# Number of segments: 3
# Length of samples: eng->1837 | hin-> 606
# Number of segments: 6
# Length of samples: eng->1834 | hin-> 603
# Number of segments: 2
# Length of samples: eng->1833 | hin-> 602
# Number of segments: 2
# Length of samples: eng->1832 | hin-> 601
# Number of segments: 2
# Length of samples: eng->1831 | hin-> 600
# Number of segments: 4
# Length of samples: eng->1829 | hin-> 598
# Number of segments: 3
# Length of samples: eng->1827 | hin-> 597
# Number of segments: 5
# Length of samples: eng->1825 | hin-> 594
# Number of segments: 6
# Length of samples: eng->1822 | hin-> 591
# Number of segments: 2
# Length of samples: eng->1821 | hin-> 590
# Number of segments: 5
# Length of samples: eng->1818 | hin-> 588
# Number of segments: 2
# Length of samples: eng->1817 | hin-> 587
# Number of segments: 4
# Length of samples: eng->1815 | hin-> 585
# Number of segments: 6
# Length of samples: eng->1812 | hin-> 582
# Number of segments: 4
# Length of samples: eng->1810 | hin-> 580
# Number of segments: 6
# Length of samples: eng->1807 | hin-> 577
# Number of segments: 6
# Length of samples: eng->1804 | hin-> 574
# Number of segments: 2
# Length of samples: eng->1803 | hin-> 573
# Number of segments: 6
# Length of samples: eng->1800 | hin-> 570
# Number of segments: 6
# Length of samples: eng->1797 | hin-> 567
# Number of segments: 6
# Length of samples: eng->1794 | hin-> 564
# Number of segments: 3
# Length of samples: eng->1793 | hin-> 562
# Number of segments: 3
# Length of samples: eng->1791 | hin-> 561
# Number of segments: 3
# Length of samples: eng->1789 | hin-> 560
# Number of segments: 5
#   6%|▌         | 594/10000 [00:01<00:22, 409.77it/s]
# Length of samples: eng->1787 | hin-> 557
# Number of segments: 4
# Length of samples: eng->1785 | hin-> 555
# Number of segments: 3
# Length of samples: eng->1783 | hin-> 554
# Number of segments: 3
# Length of samples: eng->1781 | hin-> 553
# Number of segments: 6
# Length of samples: eng->1778 | hin-> 550
# Number of segments: 3
# Length of samples: eng->1776 | hin-> 549
# Number of segments: 3
# Length of samples: eng->1775 | hin-> 547
# Number of segments: 3
# Length of samples: eng->1774 | hin-> 545
# Number of segments: 4
# Length of samples: eng->1772 | hin-> 543
# Number of segments: 4
# Length of samples: eng->1770 | hin-> 541
# Number of segments: 2
# Length of samples: eng->1769 | hin-> 540
# Number of segments: 5
# Length of samples: eng->1767 | hin-> 537
# Number of segments: 3
# Length of samples: eng->1765 | hin-> 536
# Number of segments: 5
# Length of samples: eng->1762 | hin-> 534
# Number of segments: 5
# Length of samples: eng->1760 | hin-> 531
# Number of segments: 2
# Length of samples: eng->1759 | hin-> 530
# Number of segments: 5
# Length of samples: eng->1757 | hin-> 527
# Number of segments: 4
# Length of samples: eng->1755 | hin-> 525
# Number of segments: 4
# Length of samples: eng->1753 | hin-> 523
# Number of segments: 6
# Length of samples: eng->1750 | hin-> 520
# Number of segments: 4
# Length of samples: eng->1748 | hin-> 518
# Number of segments: 5
# Length of samples: eng->1746 | hin-> 515
# Number of segments: 3
# Length of samples: eng->1744 | hin-> 514
# Number of segments: 5
# Length of samples: eng->1741 | hin-> 512
# Number of segments: 2
# Length of samples: eng->1740 | hin-> 511
# Number of segments: 3
# Length of samples: eng->1738 | hin-> 510
# Number of segments: 4
# Length of samples: eng->1736 | hin-> 508
# Number of segments: 3
# Length of samples: eng->1735 | hin-> 506
# Number of segments: 5
# Length of samples: eng->1733 | hin-> 503
# Number of segments: 3
# Length of samples: eng->1732 | hin-> 501
# Number of segments: 2
# Length of samples: eng->1731 | hin-> 500
# Number of segments: 6
# Length of samples: eng->1728 | hin-> 497
# Number of segments: 6
# Length of samples: eng->1725 | hin-> 494
# Number of segments: 4
# Length of samples: eng->1723 | hin-> 492
# Number of segments: 6
# Length of samples: eng->1720 | hin-> 489
# Number of segments: 3
# Length of samples: eng->1719 | hin-> 487
# Number of segments: 4
# Length of samples: eng->1717 | hin-> 485
# Number of segments: 2
# Length of samples: eng->1716 | hin-> 484
# Number of segments: 4
# Length of samples: eng->1714 | hin-> 482
# Number of segments: 6
# Length of samples: eng->1711 | hin-> 479
# Number of segments: 5
# Length of samples: eng->1709 | hin-> 476
# Number of segments: 2
# Length of samples: eng->1708 | hin-> 475
# Number of segments: 4
# Length of samples: eng->1706 | hin-> 473
# Number of segments: 6
# Length of samples: eng->1703 | hin-> 470
# Number of segments: 6
# Length of samples: eng->1700 | hin-> 467
# Number of segments: 3
# Length of samples: eng->1698 | hin-> 466
# Number of segments: 2
# Length of samples: eng->1697 | hin-> 465
# Number of segments: 2
# Length of samples: eng->1696 | hin-> 464
# Number of segments: 2
# Length of samples: eng->1695 | hin-> 463
# Number of segments: 5
# Length of samples: eng->1692 | hin-> 461
# Number of segments: 4
# Length of samples: eng->1690 | hin-> 459
# Number of segments: 4
# Length of samples: eng->1688 | hin-> 457
# Number of segments: 2
# Length of samples: eng->1687 | hin-> 456
# Number of segments: 5
# Length of samples: eng->1685 | hin-> 453
# Number of segments: 3
# Length of samples: eng->1683 | hin-> 452
# Number of segments: 2
# Length of samples: eng->1682 | hin-> 451
# Number of segments: 5
# Length of samples: eng->1679 | hin-> 449
# Number of segments: 6
# Length of samples: eng->1676 | hin-> 446
# Number of segments: 5
# Length of samples: eng->1674 | hin-> 443
# Number of segments: 2
# Length of samples: eng->1673 | hin-> 442
# Number of segments: 4
# Length of samples: eng->1671 | hin-> 440
# Number of segments: 2
# Length of samples: eng->1670 | hin-> 439
# Number of segments: 6
# Length of samples: eng->1667 | hin-> 436
# Number of segments: 3
# Length of samples: eng->1665 | hin-> 435
# Number of segments: 6
# Length of samples: eng->1662 | hin-> 432
# Number of segments: 4
# Length of samples: eng->1660 | hin-> 430
# Number of segments: 5
# Length of samples: eng->1657 | hin-> 428
# Number of segments: 4
# Length of samples: eng->1655 | hin-> 426
# Number of segments: 6
# Length of samples: eng->1652 | hin-> 423
# Number of segments: 4
# Length of samples: eng->1650 | hin-> 421
# Number of segments: 6
# Length of samples: eng->1647 | hin-> 418
# Number of segments: 4
# Length of samples: eng->1645 | hin-> 416
# Number of segments: 6
# Length of samples: eng->1642 | hin-> 413
# Number of segments: 2
# Length of samples: eng->1641 | hin-> 412
# Number of segments: 3
# Length of samples: eng->1640 | hin-> 410
# Number of segments: 6
# Length of samples: eng->1637 | hin-> 407
# Number of segments: 4
# Length of samples: eng->1635 | hin-> 405
# Number of segments: 3
# Length of samples: eng->1634 | hin-> 403
# Number of segments: 2
# Length of samples: eng->1633 | hin-> 402
# Number of segments: 6
# Length of samples: eng->1630 | hin-> 399
# Number of segments: 2
# Length of samples: eng->1629 | hin-> 398
# Number of segments: 2
# Length of samples: eng->1628 | hin-> 397
# Number of segments: 3
# Length of samples: eng->1626 | hin-> 396
# Number of segments: 6
# Length of samples: eng->1623 | hin-> 393
# Number of segments: 6
# Length of samples: eng->1620 | hin-> 390
# Number of segments: 5
# Length of samples: eng->1617 | hin-> 388
# Number of segments: 3
#   7%|▋         | 678/10000 [00:01<00:23, 390.75it/s]
# Length of samples: eng->1615 | hin-> 387
# Number of segments: 6
# Length of samples: eng->1612 | hin-> 384
# Number of segments: 5
# Length of samples: eng->1609 | hin-> 382
# Number of segments: 4
# Length of samples: eng->1607 | hin-> 380
# Number of segments: 3
# Length of samples: eng->1605 | hin-> 379
# Number of segments: 4
# Length of samples: eng->1603 | hin-> 377
# Number of segments: 4
# Length of samples: eng->1601 | hin-> 375
# Number of segments: 2
# Length of samples: eng->1600 | hin-> 374
# Number of segments: 4
# Length of samples: eng->1598 | hin-> 372
# Number of segments: 3
# Length of samples: eng->1596 | hin-> 371
# Number of segments: 3
# Length of samples: eng->1594 | hin-> 370
# Number of segments: 6
# Length of samples: eng->1591 | hin-> 367
# Number of segments: 3
# Length of samples: eng->1589 | hin-> 366
# Number of segments: 2
# Length of samples: eng->1588 | hin-> 365
# Number of segments: 6
# Length of samples: eng->1585 | hin-> 362
# Number of segments: 5
# Length of samples: eng->1583 | hin-> 359
# Number of segments: 4
# Length of samples: eng->1581 | hin-> 357
# Number of segments: 5
# Length of samples: eng->1579 | hin-> 354
# Number of segments: 5
# Length of samples: eng->1576 | hin-> 352
# Number of segments: 5
# Length of samples: eng->1574 | hin-> 349
# Number of segments: 5
# Length of samples: eng->1571 | hin-> 347
# Number of segments: 2
# Length of samples: eng->1570 | hin-> 346
# Number of segments: 3
# Length of samples: eng->1569 | hin-> 344
# Number of segments: 2
# Length of samples: eng->1568 | hin-> 343
# Number of segments: 4
# Length of samples: eng->1566 | hin-> 341
# Number of segments: 5
# Length of samples: eng->1563 | hin-> 339
# Number of segments: 6
# Length of samples: eng->1560 | hin-> 336
# Number of segments: 6
# Length of samples: eng->1557 | hin-> 333
# Number of segments: 3
# Length of samples: eng->1556 | hin-> 331
# Number of segments: 5
# Length of samples: eng->1553 | hin-> 329
# Number of segments: 2
# Length of samples: eng->1552 | hin-> 328
# Number of segments: 5
# Length of samples: eng->1549 | hin-> 326
# Number of segments: 6
# Length of samples: eng->1546 | hin-> 323
# Number of segments: 2
# Length of samples: eng->1545 | hin-> 322
# Number of segments: 4
# Length of samples: eng->1543 | hin-> 320
# Number of segments: 6
# Length of samples: eng->1540 | hin-> 317
# Number of segments: 2
# Length of samples: eng->1539 | hin-> 316
# Number of segments: 2
# Length of samples: eng->1538 | hin-> 315
# Number of segments: 2
# Length of samples: eng->1537 | hin-> 314
# Number of segments: 3
# Length of samples: eng->1536 | hin-> 312
# Number of segments: 6
# Length of samples: eng->1533 | hin-> 309
# Number of segments: 6
# Length of samples: eng->1530 | hin-> 306
# Number of segments: 4
# Length of samples: eng->1528 | hin-> 304
# Number of segments: 6
# Length of samples: eng->1525 | hin-> 301
# Number of segments: 5
# Length of samples: eng->1522 | hin-> 299
# Number of segments: 3
# Length of samples: eng->1521 | hin-> 297
# Number of segments: 5
# Length of samples: eng->1519 | hin-> 294
# Number of segments: 6
# Length of samples: eng->1516 | hin-> 291
# Number of segments: 4
# Length of samples: eng->1514 | hin-> 289
# Number of segments: 3
# Length of samples: eng->1512 | hin-> 288
# Number of segments: 6
# Length of samples: eng->1509 | hin-> 285
# Number of segments: 6
# Length of samples: eng->1506 | hin-> 282
# Number of segments: 2
# Length of samples: eng->1505 | hin-> 281
# Number of segments: 5
# Length of samples: eng->1503 | hin-> 278
# Number of segments: 6
# Length of samples: eng->1500 | hin-> 275
# Number of segments: 6
# Length of samples: eng->1497 | hin-> 272
# Number of segments: 5
# Length of samples: eng->1495 | hin-> 269
# Number of segments: 3
# Length of samples: eng->1494 | hin-> 267
# Number of segments: 2
# Length of samples: eng->1493 | hin-> 266
# Number of segments: 4
# Length of samples: eng->1491 | hin-> 264
# Number of segments: 4
# Length of samples: eng->1489 | hin-> 262
# Number of segments: 6
# Length of samples: eng->1486 | hin-> 259
# Number of segments: 4
# Length of samples: eng->1484 | hin-> 257
# Number of segments: 6
# Length of samples: eng->1481 | hin-> 254
# Number of segments: 4
# Length of samples: eng->1479 | hin-> 252
# Number of segments: 2
# Length of samples: eng->1478 | hin-> 251
# Number of segments: 2
# Length of samples: eng->1477 | hin-> 250
# Number of segments: 3
# Length of samples: eng->1475 | hin-> 249
# Number of segments: 6
# Length of samples: eng->1472 | hin-> 246
# Number of segments: 3
# Length of samples: eng->1471 | hin-> 244
# Number of segments: 6
# Length of samples: eng->1468 | hin-> 241
# Number of segments: 6
# Length of samples: eng->1465 | hin-> 238
# Number of segments: 5
# Length of samples: eng->1463 | hin-> 235
# Number of segments: 6
# Length of samples: eng->1460 | hin-> 232
# Number of segments: 6
# Length of samples: eng->1457 | hin-> 229
# Number of segments: 4
# Length of samples: eng->1455 | hin-> 227
# Number of segments: 3
# Length of samples: eng->1453 | hin-> 226
# Number of segments: 3
# Length of samples: eng->1451 | hin-> 225
# Number of segments: 4
#   8%|▊         | 775/10000 [00:01<00:21, 435.28it/s]
# Length of samples: eng->1449 | hin-> 223
# Number of segments: 4
# Length of samples: eng->1447 | hin-> 221
# Number of segments: 2
# Length of samples: eng->1446 | hin-> 220
# Number of segments: 2
# Length of samples: eng->1445 | hin-> 219
# Number of segments: 2
# Length of samples: eng->1444 | hin-> 218
# Number of segments: 2
# Length of samples: eng->1443 | hin-> 217
# Number of segments: 3
# Length of samples: eng->1442 | hin-> 215
# Number of segments: 4
# Length of samples: eng->1440 | hin-> 213
# Number of segments: 4
# Length of samples: eng->1438 | hin-> 211
# Number of segments: 6
# Length of samples: eng->1435 | hin-> 208
# Number of segments: 5
# Length of samples: eng->1433 | hin-> 205
# Number of segments: 2
# Length of samples: eng->1432 | hin-> 204
# Number of segments: 2
# Length of samples: eng->1431 | hin-> 203
# Number of segments: 6
# Length of samples: eng->1428 | hin-> 200
# Number of segments: 3
# Length of samples: eng->1427 | hin-> 198
# Number of segments: 3
# Length of samples: eng->1425 | hin-> 197
# Number of segments: 5
# Length of samples: eng->1422 | hin-> 195
# Number of segments: 6
# Length of samples: eng->1419 | hin-> 192
# Number of segments: 3
# Length of samples: eng->1417 | hin-> 191
# Number of segments: 2
# Length of samples: eng->1416 | hin-> 190
# Number of segments: 4
# Length of samples: eng->1414 | hin-> 188
# Number of segments: 3
# Length of samples: eng->1412 | hin-> 187
# Number of segments: 3
# Length of samples: eng->1411 | hin-> 185
# Number of segments: 2
# Length of samples: eng->1410 | hin-> 184
# Number of segments: 2
# Length of samples: eng->1409 | hin-> 183
# Number of segments: 4
# Length of samples: eng->1407 | hin-> 181
# Number of segments: 4
# Length of samples: eng->1405 | hin-> 179
# Number of segments: 2
# Length of samples: eng->1404 | hin-> 178
# Number of segments: 6
# Length of samples: eng->1401 | hin-> 175
# Number of segments: 5
# Length of samples: eng->1399 | hin-> 172
# Number of segments: 6
# Length of samples: eng->1396 | hin-> 169
# Number of segments: 6
# Length of samples: eng->1393 | hin-> 166
# Number of segments: 4
# Length of samples: eng->1391 | hin-> 164
# Number of segments: 6
# Length of samples: eng->1388 | hin-> 161
# Number of segments: 3
# Length of samples: eng->1386 | hin-> 160
# Number of segments: 5
# Length of samples: eng->1383 | hin-> 158
# Number of segments: 6
# Length of samples: eng->1380 | hin-> 155
# Number of segments: 5
# Length of samples: eng->1377 | hin-> 153
# Number of segments: 5
# Length of samples: eng->1375 | hin-> 150
# Number of segments: 5
# Length of samples: eng->1373 | hin-> 147
# Number of segments: 3
# Length of samples: eng->1372 | hin-> 145
# Number of segments: 2
# Length of samples: eng->1371 | hin-> 144
# Number of segments: 2
# Length of samples: eng->1370 | hin-> 143
# Number of segments: 3
# Length of samples: eng->1368 | hin-> 142
# Number of segments: 3
# Length of samples: eng->1366 | hin-> 141
# Number of segments: 6
# Length of samples: eng->1363 | hin-> 138
# Number of segments: 6
# Length of samples: eng->1360 | hin-> 135
# Number of segments: 3
# Length of samples: eng->1359 | hin-> 133
# Number of segments: 5
# Length of samples: eng->1357 | hin-> 130
# Number of segments: 3
# Length of samples: eng->1355 | hin-> 129
# Number of segments: 2
# Length of samples: eng->1354 | hin-> 128
# Number of segments: 3
# Length of samples: eng->1353 | hin-> 126
# Number of segments: 6
# Length of samples: eng->1350 | hin-> 123
# Number of segments: 2
# Length of samples: eng->1349 | hin-> 122
# Number of segments: 2
# Length of samples: eng->1348 | hin-> 121
# Number of segments: 5
# Length of samples: eng->1345 | hin-> 119
# Number of segments: 6
# Length of samples: eng->1342 | hin-> 116
# Number of segments: 2
# Length of samples: eng->1341 | hin-> 115
# Number of segments: 4
# Length of samples: eng->1339 | hin-> 113
# Number of segments: 6
# Length of samples: eng->1336 | hin-> 110
# Number of segments: 4
# Length of samples: eng->1334 | hin-> 108
# Number of segments: 2
# Length of samples: eng->1333 | hin-> 107
# Number of segments: 4
# Length of samples: eng->1331 | hin-> 105
# Number of segments: 6
# Length of samples: eng->1328 | hin-> 102
# Number of segments: 5
# Length of samples: eng->1325 | hin-> 100
# Number of segments: 2
# Length of samples: eng->1324 | hin-> 99
# Number of segments: 4
# Length of samples: eng->1322 | hin-> 97
# Number of segments: 2
# Length of samples: eng->1321 | hin-> 96
# Number of segments: 2
# Length of samples: eng->1320 | hin-> 95
# Number of segments: 6
# Length of samples: eng->1317 | hin-> 92
# Number of segments: 6
# Length of samples: eng->1314 | hin-> 89
# Number of segments: 4
# Length of samples: eng->1312 | hin-> 87
# Number of segments: 4
# Length of samples: eng->1310 | hin-> 85
# Number of segments: 2
# Length of samples: eng->1309 | hin-> 84
# Number of segments: 5
# Length of samples: eng->1306 | hin-> 82
# Number of segments: 6
# Length of samples: eng->1303 | hin-> 79
# Number of segments: 2
# Length of samples: eng->1302 | hin-> 78
# Number of segments: 6
# Length of samples: eng->1299 | hin-> 75
# Number of segments: 4
# Length of samples: eng->1297 | hin-> 73
# Number of segments: 3
# Length of samples: eng->1296 | hin-> 71
# Number of segments: 2
# Length of samples: eng->1295 | hin-> 70
# Number of segments: 6
# Length of samples: eng->1292 | hin-> 67
# Number of segments: 3
# Length of samples: eng->1290 | hin-> 66
# Number of segments: 4
# Length of samples: eng->1288 | hin-> 64
# Number of segments: 4
# Length of samples: eng->1286 | hin-> 62
# Number of segments: 6
# Length of samples: eng->1283 | hin-> 59
# Number of segments: 3
# Length of samples: eng->1282 | hin-> 57
# Number of segments: 2
# Length of samples: eng->1281 | hin-> 56
# Number of segments: 5
# Length of samples: eng->1279 | hin-> 53
# Number of segments: 2
# Length of samples: eng->1278 | hin-> 52
# Number of segments: 3
# Length of samples: eng->1276 | hin-> 51
# Number of segments: 5
# Length of samples: eng->1274 | hin-> 48
# Number of segments: 5
# Length of samples: eng->1272 | hin-> 45
# Number of segments: 4
# Length of samples: eng->1270 | hin-> 43
# Number of segments: 3
# Length of samples: eng->1268 | hin-> 42
# Number of segments: 6
# Length of samples: eng->1265 | hin-> 39
# Number of segments: 3
# Length of samples: eng->1264 | hin-> 37
# Number of segments: 5
# Length of samples: eng->1262 | hin-> 34
# Number of segments: 4
#   8%|▊         | 818/10000 [00:02<00:23, 389.85it/s]
# Length of samples: eng->1260 | hin-> 32
# Number of segments: 5
# Length of samples: eng->1257 | hin-> 30
# Number of segments: 2
# Length of samples: eng->1256 | hin-> 29
# Number of segments: 5
# Length of samples: eng->1254 | hin-> 26
# Number of segments: 3
# Length of samples: eng->1253 | hin-> 24
# Number of segments: 6
# Length of samples: eng->1250 | hin-> 21
# Number of segments: 4
# Length of samples: eng->1248 | hin-> 19
# Number of segments: 4
# Length of samples: eng->1246 | hin-> 17
# Number of segments: 6
# Length of samples: eng->1243 | hin-> 14
# Number of segments: 5
# Length of samples: eng->1241 | hin-> 11
# Number of segments: 2
# Length of samples: eng->1240 | hin-> 10
# Number of segments: 2
# Length of samples: eng->1239 | hin-> 9
# Number of segments: 6
# Length of samples: eng->1236 | hin-> 6
# Number of segments: 5
# Length of samples: eng->1233 | hin-> 4
# Number of segments: 3
# Length of samples: eng->1231 | hin-> 3
# Number of segments: 3
# Length of samples: eng->1230 | hin-> 1
# Number of segments: 4
